# %% [markdown]
# #### Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [raw]
# The Seaborn library is a popular data visualization library in Python that is built on top of Matplotlib. It provides a high-level interface for creating informative and visually appealing statistical graphics. Here are five commonly used plots in Seaborn along with their uses:
#
# Scatter Plot:
#
# Uses: A scatter plot shows the relationship between two numerical variables. It is useful for identifying patterns or trends, detecting outliers, and examining the correlation between variables.
# Line Plot:
#
# Uses: A line plot displays the relationship between two continuous variables over a continuous interval. It is often used to visualize trends, changes over time, or sequential data.
# Histogram:
#
# Uses: A histogram represents the distribution of a single numerical variable. It displays the frequency or count of observations falling into different bins or intervals, allowing you to understand the data's underlying distribution and detect outliers.
# Bar Plot:
#
# Uses: A bar plot (or bar chart) displays categorical data with rectangular bars, where the length of each bar represents a certain value. It is commonly used to compare values across different categories or groups.
# Box Plot:
#
# Uses: A box plot (or box-and-whisker plot) provides a summary of the distribution of a numerical variable. It displays the quartiles, median, and any potential outliers. Box plots are useful for visualizing the spread and skewness of the data, as well as identifying potential anomalies.

# %% [markdown]
# #### Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns

# Load the "fmri" dataset
fmri_data = sns.load_dataset("fmri")

# Plot the line plot
sns.lineplot(data=fmri_data, x="timepoint", y="signal", hue="event", style="region")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# #### Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "titanic" dataset
titanic_data = sns.load_dataset("titanic")

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Box plot for 'age'
sns.boxplot(data=titanic_data, x='pclass', y='age', ax=axes[0])
axes[0].set_title('Box Plot of Age by Passenger Class')

# Box plot for 'fare'
sns.boxplot(data=titanic_data, x='pclass', y='fare', ax=axes[1])
axes[1].set_title('Box Plot of Fare by Passenger Class')

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "diamonds" dataset
diamonds_data = sns.load_dataset("diamonds")

# Plot histogram with hue parameter
sns.histplot(data=diamonds_data, x='price', hue='cut', multiple='stack')

# Set plot title and labels
plt.title('Histogram of Diamond Prices by Cut')
plt.xlabel('Price')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# #### Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
import seaborn as sns

# Load the "iris" dataset
iris_data = sns.load_dataset("iris")

# Plot pair plot with hue parameter
sns.pairplot(data=iris_data, hue='species')

# %% [markdown]
# #### Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
# Load the "flights" dataset
flights_data = sns.load_dataset("flights")
# Pivot the data to create a matrix for heatmap
flights_pivot = flights_data.pivot("month", "year", "passengers")
# Plot the heatmap
sns.heatmap(data=flights_pivot, cmap="YlGnBu", annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>
